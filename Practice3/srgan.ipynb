# %%
import os
from copy import deepcopy
from math import sqrt

import torch
import torchvision
import torch.nn as nn
from PIL import Image
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm

from models.srgan import Generator, Discriminator

# %%
SCALE_FACTOR = 4
CROP_SIZE = 32
IMG_FORMATS = 'bmp', 'dng', 'jpeg', 'jpg', 'mpo', 'png', 'tif', 'tiff', 'webp', 'pfm'  # include image suffixes

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# Total Variation Loss
class TVLoss(nn.Module):
    def __init__(self, tv_loss_weight=1):
        super(TVLoss, self).__init__()
        self.tv_loss_weight = tv_loss_weight

    def forward(self, x):
        batch_size = x.size()[0]
        h_x = x.size()[2]
        w_x = x.size()[3]
        count_h = self.tensor_size(x[:, :, 1:, :])
        count_w = self.tensor_size(x[:, :, :, 1:])
        h_tv = torch.pow((x[:, :, 1:, :] - x[:, :, :h_x - 1, :]), 2).sum()
        w_tv = torch.pow((x[:, :, :, 1:] - x[:, :, :, :w_x - 1]), 2).sum()
        return self.tv_loss_weight * 2 * (h_tv / count_h + w_tv / count_w) / batch_size

    @staticmethod
    def tensor_size(t):
        return t.size()[1] * t.size()[2] * t.size()[3]

# %%
class GeneratorLoss(nn.Module):
    def __init__(self):
        super().__init__()
        vgg = torchvision.models.vgg.vgg16(weights='VGG16_Weights.IMAGENET1K_V1')
        loss_net = nn.Sequential(*list(vgg.features)[:31]).eval()
        for param in loss_net.parameters():
            param.requires_grad = False
        self.loss_net = loss_net.to(device)
        self.mse_loss = nn.MSELoss()
        self.tv_loss = TVLoss()

    def forward(self, fakes, p, targets):
        # p: (G)fakes: fake_images, (D)probabilities of real_images, targets: target_images(high-resolution)
        image_loss = self.mse_loss(fakes, targets)  # Image Loss
        adversarial_loss = torch.mean(1 - p)  # Adversarial Loss
        perception_loss = self.mse_loss(self.loss_net(fakes), self.loss_net(targets))  # Perception Loss
        tv_loss = self.tv_loss(fakes)  # TV Loss

        return image_loss + 0.001 * adversarial_loss + 0.006 * perception_loss + 2e-8 * tv_loss

# %%
class DiscriminatorLoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.bce_loss = nn.BCELoss()

    def forward(self, p, p_gt):
        # p: probability of real_image, p_gt: probability(ground truth) of real_image
        return self.bce_loss(p, torch.zeros_like(p, device=device)) + self.bce_loss(p_gt, torch.ones_like(p_gt, device=device))

# %%
# train_dataset
class LoadDataset(Dataset):
    def __init__(self, path, scale_factor=SCALE_FACTOR, crop_size=CROP_SIZE):
        super().__init__()
        scale_resize = int(sqrt(scale_factor))
        crop_size_ = crop_size - (crop_size % scale_resize) # Valid crop size

        self.imgs_path_list = [os.path.join(path, x) for x in os.listdir(path) if x.split('.')[-1].lower() in IMG_FORMATS]

        self.image_transform = transforms.Compose([
            transforms.CenterCrop(crop_size_),
            transforms.Resize(crop_size_ // scale_resize, interpolation=Image.BICUBIC),
            transforms.ToTensor(),
        ])

        self.label_transform = transforms.Compose([
            transforms.CenterCrop(crop_size_),
            transforms.ToTensor(),
        ])

    def __len__(self):
        return len(self.imgs_path_list)

    def __getitem__(self, index):
        img = Image.open(self.imgs_path_list[index])
        label = img.copy()

        img = self.image_transform(img)
        label = self.label_transform(label)
        return img, label

# %%
# test_dataloader
class LoadImages:
    def __init__(self, path, scale_factor=SCALE_FACTOR):
        self.scale_factor = scale_factor
        self.scale_resize = int(sqrt(scale_factor))
        self.imgs_path_list = [os.path.join(path, x) for x in os.listdir(path) if x.split('.')[-1].lower() in IMG_FORMATS]
        self.num_files = len(self.imgs_path_list)

    def __len__(self):
        return self.num_files

    def __iter__(self):
        self.count = 0
        return self

    def __next__(self):
        if self.count == self.num_files:
            raise StopIteration
        img_path = self.imgs_path_list[self.count]
        self.count += 1

        img_name = img_path.split(os.sep)[-1]
        img0 = Image.open(img_path)
        img = img0.resize((
            int(img0.size[0] / self.scale_resize),
            int(img0.size[1] / self.scale_resize)
        ),
            Image.BICUBIC,  # scale the image via bicubic interpolation
        )

        # img = img0.resize((
        #     int(img0.size[0] / self.scale_factor),
        #     int(img0.size[1] / self.scale_factor)
        # ),
        #     Image.BICUBIC,  # scale the image via bicubic interpolation
        # )

        img_ = transforms.ToTensor()(img).view(1, -1, img.size[1], img.size[0])

        return img_, img_name

# %% [markdown]
# # Train

# %%
train_generator = Generator(in_channels=3, scale_factor=SCALE_FACTOR).to(device)
train_discriminator = Discriminator(in_channels=3).to(device)

optimizerG = torch.optim.Adam(train_generator.parameters(), lr=1e-4)
optimizerD = torch.optim.Adam(train_discriminator.parameters(), lr=1e-3)
lr_schedulerG = torch.optim.lr_scheduler.StepLR(optimizer=optimizerG, step_size=20, gamma=0.5)
lr_schedulerD = torch.optim.lr_scheduler.StepLR(optimizer=optimizerD, step_size=20, gamma=0.5)

gloss_fn = GeneratorLoss()
dloss_fn = DiscriminatorLoss()

train_dataset = LoadDataset('data/train')
train_loader = DataLoader(dataset=train_dataset, batch_size=256, shuffle=True, num_workers=0)

# %%
epochs = 300
for epoch in range(epochs):
    train_generator.train()
    train_discriminator.train()
    mloss = torch.zeros(2, device=device)  # mean_loss of generator and discriminator

    pbar = tqdm(enumerate(train_loader), total=len(train_loader), desc=f'Epoch {epoch}/{epochs}', unit='batches')
    for i, (images, targets) in pbar:
        images, targets = images.to(device), targets.to(device)  # images: low_resolution, targets: high-resolution
        fakes = train_generator(images)  # fake_images
        ps = train_discriminator(fakes)  # probabilities of real_images
        ps_gt = train_discriminator(targets)  # probabilities(ground truth) of real_images

        gloss = gloss_fn(fakes, ps, targets)
        optimizerG.zero_grad()
        gloss.backward()
        optimizerG.step()

        dloss = dloss_fn(ps.detach(), ps_gt)
        optimizerD.zero_grad()
        dloss.backward()
        optimizerD.step()

        mloss[0] = (mloss[0] * i + gloss) / (i + 1)  # mean_loss of generator
        mloss[1] = (mloss[1] * i + dloss) / (i + 1)  # mean_loss of discriminator
        mem = f'{torch.cuda.memory_reserved() / 1e9 if torch.cuda.is_available() else 0:.3g}G'  # GPU_mem
        pbar.set_postfix(gloss=mloss[0].item(), dloss=mloss[1].item(), GPU_mem=mem)

    lr_schedulerG.step()
    lr_schedulerD.step()

    ckpt = {  # checkpoint
        'epoch': epoch,
        'generator': deepcopy(train_generator).half(),
        'discriminator': deepcopy(train_discriminator).half(),
        'optimizerG': optimizerG.state_dict(),
        'optimizerD': optimizerD.state_dict(),
    }
    torch.save(ckpt, 'srgan.pt')
# Out:
# Epoch 0/300: 100%|██████████| 2/2 [00:01<00:00,  1.70batches/s, GPU_mem=2.39G, dloss=87.3, gloss=0.0107]
# Epoch 1/300: 100%|██████████| 2/2 [00:00<00:00,  2.58batches/s, GPU_mem=2.39G, dloss=88.5, gloss=0.0103]
# Epoch 2/300: 100%|██████████| 2/2 [00:00<00:00,  2.59batches/s, GPU_mem=2.39G, dloss=87.4, gloss=0.0102]
# Epoch 3/300: 100%|██████████| 2/2 [00:00<00:00,  2.52batches/s, GPU_mem=2.39G, dloss=87.1, gloss=0.0102]
# Epoch 4/300: 100%|██████████| 2/2 [00:00<00:00,  2.57batches/s, GPU_mem=2.39G, dloss=88.8, gloss=0.0104]
# Epoch 5/300: 100%|██████████| 2/2 [00:00<00:00,  2.54batches/s, GPU_mem=2.39G, dloss=87.8, gloss=0.0107]
# Epoch 6/300: 100%|██████████| 2/2 [00:00<00:00,  2.56batches/s, GPU_mem=2.39G, dloss=86, gloss=0.0105]
# Epoch 7/300: 100%|██████████| 2/2 [00:00<00:00,  2.57batches/s, GPU_mem=2.39G, dloss=87.7, gloss=0.0106]
# Epoch 8/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=87.1, gloss=0.0103]
# Epoch 9/300: 100%|██████████| 2/2 [00:00<00:00,  2.54batches/s, GPU_mem=2.39G, dloss=86.4, gloss=0.0106]
# Epoch 10/300: 100%|██████████| 2/2 [00:00<00:00,  2.54batches/s, GPU_mem=2.39G, dloss=85.6, gloss=0.0106]
# Epoch 11/300: 100%|██████████| 2/2 [00:00<00:00,  2.51batches/s, GPU_mem=2.39G, dloss=88.5, gloss=0.0102]
# Epoch 12/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=88.9, gloss=0.00983]
# Epoch 13/300: 100%|██████████| 2/2 [00:00<00:00,  2.49batches/s, GPU_mem=2.39G, dloss=89.3, gloss=0.0103]
# Epoch 14/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=87.3, gloss=0.00981]
# Epoch 15/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=87.8, gloss=0.0099]
# Epoch 16/300: 100%|██████████| 2/2 [00:00<00:00,  2.59batches/s, GPU_mem=2.39G, dloss=84.7, gloss=0.0104]
# Epoch 17/300: 100%|██████████| 2/2 [00:00<00:00,  2.57batches/s, GPU_mem=2.39G, dloss=88.1, gloss=0.00968]
# Epoch 18/300: 100%|██████████| 2/2 [00:00<00:00,  2.50batches/s, GPU_mem=2.39G, dloss=86.9, gloss=0.01]
# Epoch 19/300: 100%|██████████| 2/2 [00:00<00:00,  2.52batches/s, GPU_mem=2.39G, dloss=88.9, gloss=0.0106]
# Epoch 20/300: 100%|██████████| 2/2 [00:00<00:00,  2.54batches/s, GPU_mem=2.39G, dloss=87.1, gloss=0.0101]
# Epoch 21/300: 100%|██████████| 2/2 [00:00<00:00,  2.55batches/s, GPU_mem=2.39G, dloss=88, gloss=0.00954]
# Epoch 22/300: 100%|██████████| 2/2 [00:00<00:00,  2.56batches/s, GPU_mem=2.39G, dloss=86.4, gloss=0.00952]
# Epoch 23/300: 100%|██████████| 2/2 [00:00<00:00,  2.54batches/s, GPU_mem=2.39G, dloss=89, gloss=0.00981]
# Epoch 24/300: 100%|██████████| 2/2 [00:00<00:00,  2.56batches/s, GPU_mem=2.39G, dloss=87, gloss=0.00965]
# Epoch 25/300: 100%|██████████| 2/2 [00:00<00:00,  2.55batches/s, GPU_mem=2.39G, dloss=90.2, gloss=0.01]
# Epoch 26/300: 100%|██████████| 2/2 [00:00<00:00,  2.54batches/s, GPU_mem=2.39G, dloss=91.5, gloss=0.00954]
# Epoch 27/300: 100%|██████████| 2/2 [00:00<00:00,  2.59batches/s, GPU_mem=2.39G, dloss=87.8, gloss=0.0094]
# Epoch 28/300: 100%|██████████| 2/2 [00:00<00:00,  2.59batches/s, GPU_mem=2.39G, dloss=89.1, gloss=0.00926]
# Epoch 29/300: 100%|██████████| 2/2 [00:00<00:00,  2.59batches/s, GPU_mem=2.39G, dloss=86.8, gloss=0.00989]
# Epoch 30/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=88.4, gloss=0.00952]
# Epoch 31/300: 100%|██████████| 2/2 [00:00<00:00,  2.50batches/s, GPU_mem=2.39G, dloss=88.8, gloss=0.00953]
# Epoch 32/300: 100%|██████████| 2/2 [00:00<00:00,  2.57batches/s, GPU_mem=2.39G, dloss=87.4, gloss=0.00944]
# Epoch 33/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=86.2, gloss=0.00962]
# Epoch 34/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=88.2, gloss=0.00953]
# Epoch 35/300: 100%|██████████| 2/2 [00:00<00:00,  2.58batches/s, GPU_mem=2.39G, dloss=85.4, gloss=0.0099]
# Epoch 36/300: 100%|██████████| 2/2 [00:00<00:00,  2.54batches/s, GPU_mem=2.39G, dloss=88.7, gloss=0.00917]
# Epoch 37/300: 100%|██████████| 2/2 [00:00<00:00,  2.57batches/s, GPU_mem=2.39G, dloss=85.6, gloss=0.00958]
# Epoch 38/300: 100%|██████████| 2/2 [00:00<00:00,  2.54batches/s, GPU_mem=2.39G, dloss=86.2, gloss=0.00963]
# Epoch 39/300: 100%|██████████| 2/2 [00:00<00:00,  2.56batches/s, GPU_mem=2.39G, dloss=86.1, gloss=0.00959]
# Epoch 40/300: 100%|██████████| 2/2 [00:00<00:00,  2.55batches/s, GPU_mem=2.39G, dloss=87.9, gloss=0.00932]
# Epoch 41/300: 100%|██████████| 2/2 [00:00<00:00,  2.52batches/s, GPU_mem=2.39G, dloss=87.4, gloss=0.00946]
# Epoch 42/300: 100%|██████████| 2/2 [00:00<00:00,  2.52batches/s, GPU_mem=2.39G, dloss=88.9, gloss=0.0101]
# Epoch 43/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=87.8, gloss=0.00937]
# Epoch 44/300: 100%|██████████| 2/2 [00:00<00:00,  2.52batches/s, GPU_mem=2.39G, dloss=88.8, gloss=0.00937]
# Epoch 45/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=88.3, gloss=0.00948]
# Epoch 46/300: 100%|██████████| 2/2 [00:00<00:00,  2.49batches/s, GPU_mem=2.39G, dloss=87.6, gloss=0.00944]
# Epoch 47/300: 100%|██████████| 2/2 [00:00<00:00,  2.55batches/s, GPU_mem=2.39G, dloss=88.3, gloss=0.00939]
# Epoch 48/300: 100%|██████████| 2/2 [00:00<00:00,  2.52batches/s, GPU_mem=2.39G, dloss=84.8, gloss=0.00957]
# Epoch 49/300: 100%|██████████| 2/2 [00:00<00:00,  2.55batches/s, GPU_mem=2.39G, dloss=88.8, gloss=0.00941]
# Epoch 50/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=86.2, gloss=0.0098]
# Epoch 51/300: 100%|██████████| 2/2 [00:00<00:00,  2.56batches/s, GPU_mem=2.39G, dloss=85.7, gloss=0.00951]
# Epoch 52/300: 100%|██████████| 2/2 [00:00<00:00,  2.48batches/s, GPU_mem=2.39G, dloss=87.1, gloss=0.00951]
# Epoch 53/300: 100%|██████████| 2/2 [00:00<00:00,  2.54batches/s, GPU_mem=2.39G, dloss=86, gloss=0.0102]
# Epoch 54/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=88.1, gloss=0.00935]
# Epoch 55/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=87.7, gloss=0.00936]
# Epoch 56/300: 100%|██████████| 2/2 [00:00<00:00,  2.57batches/s, GPU_mem=2.39G, dloss=87.7, gloss=0.00951]
# Epoch 57/300: 100%|██████████| 2/2 [00:00<00:00,  2.56batches/s, GPU_mem=2.39G, dloss=88.2, gloss=0.00964]
# Epoch 58/300: 100%|██████████| 2/2 [00:00<00:00,  2.55batches/s, GPU_mem=2.39G, dloss=86.9, gloss=0.00954]
# Epoch 59/300: 100%|██████████| 2/2 [00:00<00:00,  2.55batches/s, GPU_mem=2.39G, dloss=87.8, gloss=0.00944]
# Epoch 60/300: 100%|██████████| 2/2 [00:00<00:00,  2.49batches/s, GPU_mem=2.39G, dloss=88.6, gloss=0.00911]
# Epoch 61/300: 100%|██████████| 2/2 [00:00<00:00,  2.50batches/s, GPU_mem=2.39G, dloss=88.1, gloss=0.0091]
# Epoch 62/300: 100%|██████████| 2/2 [00:00<00:00,  2.43batches/s, GPU_mem=2.39G, dloss=86.8, gloss=0.00982]
# Epoch 63/300: 100%|██████████| 2/2 [00:00<00:00,  2.31batches/s, GPU_mem=2.39G, dloss=88, gloss=0.00936]
# Epoch 64/300: 100%|██████████| 2/2 [00:00<00:00,  2.49batches/s, GPU_mem=2.39G, dloss=87.2, gloss=0.00948]
# Epoch 65/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=87.3, gloss=0.0092]
# Epoch 66/300: 100%|██████████| 2/2 [00:00<00:00,  2.55batches/s, GPU_mem=2.39G, dloss=86.9, gloss=0.00914]
# Epoch 67/300: 100%|██████████| 2/2 [00:00<00:00,  2.52batches/s, GPU_mem=2.39G, dloss=86.7, gloss=0.00919]
# Epoch 68/300: 100%|██████████| 2/2 [00:00<00:00,  2.56batches/s, GPU_mem=2.39G, dloss=87.7, gloss=0.00894]
# Epoch 69/300: 100%|██████████| 2/2 [00:00<00:00,  2.52batches/s, GPU_mem=2.39G, dloss=89.1, gloss=0.00955]
# Epoch 70/300: 100%|██████████| 2/2 [00:00<00:00,  2.59batches/s, GPU_mem=2.39G, dloss=87.6, gloss=0.00937]
# Epoch 71/300: 100%|██████████| 2/2 [00:00<00:00,  2.57batches/s, GPU_mem=2.39G, dloss=88.4, gloss=0.00934]
# Epoch 72/300: 100%|██████████| 2/2 [00:00<00:00,  2.55batches/s, GPU_mem=2.39G, dloss=87.1, gloss=0.00948]
# Epoch 73/300: 100%|██████████| 2/2 [00:01<00:00,  1.74batches/s, GPU_mem=2.39G, dloss=87.3, gloss=0.00951]
# Epoch 74/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=85.7, gloss=0.00941]
# Epoch 75/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=87.6, gloss=0.00937]
# Epoch 76/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=86.4, gloss=0.00891]
# Epoch 77/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=87.4, gloss=0.00909]
# Epoch 78/300: 100%|██████████| 2/2 [00:01<00:00,  1.78batches/s, GPU_mem=2.39G, dloss=88.2, gloss=0.00926]
# Epoch 79/300: 100%|██████████| 2/2 [00:01<00:00,  1.75batches/s, GPU_mem=2.39G, dloss=86.7, gloss=0.00942]
# Epoch 80/300: 100%|██████████| 2/2 [00:01<00:00,  1.83batches/s, GPU_mem=2.39G, dloss=86.1, gloss=0.00922]
# Epoch 81/300: 100%|██████████| 2/2 [00:01<00:00,  1.76batches/s, GPU_mem=2.39G, dloss=85.1, gloss=0.00959]
# Epoch 82/300: 100%|██████████| 2/2 [00:01<00:00,  1.78batches/s, GPU_mem=2.39G, dloss=85.5, gloss=0.009]
# Epoch 83/300: 100%|██████████| 2/2 [00:01<00:00,  1.84batches/s, GPU_mem=2.39G, dloss=85.9, gloss=0.00961]
# Epoch 84/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=86.8, gloss=0.00931]
# Epoch 85/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=86.5, gloss=0.0093]
# Epoch 86/300: 100%|██████████| 2/2 [00:01<00:00,  1.78batches/s, GPU_mem=2.39G, dloss=87.6, gloss=0.00956]
# Epoch 87/300: 100%|██████████| 2/2 [00:01<00:00,  1.76batches/s, GPU_mem=2.39G, dloss=87.6, gloss=0.00889]
# Epoch 88/300: 100%|██████████| 2/2 [00:01<00:00,  1.83batches/s, GPU_mem=2.39G, dloss=89.9, gloss=0.00899]
# Epoch 89/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=85.9, gloss=0.00909]
# Epoch 90/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=84.6, gloss=0.00916]
# Epoch 91/300: 100%|██████████| 2/2 [00:01<00:00,  1.63batches/s, GPU_mem=2.39G, dloss=87.5, gloss=0.0091]
# Epoch 92/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=86.6, gloss=0.00882]
# Epoch 93/300: 100%|██████████| 2/2 [00:01<00:00,  1.86batches/s, GPU_mem=2.39G, dloss=88.6, gloss=0.00925]
# Epoch 94/300: 100%|██████████| 2/2 [00:01<00:00,  1.87batches/s, GPU_mem=2.39G, dloss=86.8, gloss=0.00912]
# Epoch 95/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=86.5, gloss=0.00893]
# Epoch 96/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=87.3, gloss=0.00933]
# Epoch 97/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=88.8, gloss=0.00955]
# Epoch 98/300: 100%|██████████| 2/2 [00:01<00:00,  1.83batches/s, GPU_mem=2.39G, dloss=87.5, gloss=0.00923]
# Epoch 99/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=86.7, gloss=0.00955]
# Epoch 100/300: 100%|██████████| 2/2 [00:01<00:00,  1.83batches/s, GPU_mem=2.39G, dloss=88.2, gloss=0.00917]
# Epoch 101/300: 100%|██████████| 2/2 [00:00<00:00,  2.14batches/s, GPU_mem=2.39G, dloss=87.1, gloss=0.00909]
# Epoch 102/300: 100%|██████████| 2/2 [00:00<00:00,  2.49batches/s, GPU_mem=2.39G, dloss=86.1, gloss=0.00926]
# Epoch 103/300: 100%|██████████| 2/2 [00:00<00:00,  2.63batches/s, GPU_mem=2.39G, dloss=88.3, gloss=0.00919]
# Epoch 104/300: 100%|██████████| 2/2 [00:00<00:00,  2.54batches/s, GPU_mem=2.39G, dloss=87, gloss=0.0088]
# Epoch 105/300: 100%|██████████| 2/2 [00:00<00:00,  2.50batches/s, GPU_mem=2.39G, dloss=85.5, gloss=0.00948]
# Epoch 106/300: 100%|██████████| 2/2 [00:00<00:00,  2.56batches/s, GPU_mem=2.39G, dloss=85.9, gloss=0.00903]
# Epoch 107/300: 100%|██████████| 2/2 [00:00<00:00,  2.42batches/s, GPU_mem=2.39G, dloss=88.1, gloss=0.00908]
# Epoch 108/300: 100%|██████████| 2/2 [00:00<00:00,  2.19batches/s, GPU_mem=2.39G, dloss=89.3, gloss=0.0096]
# Epoch 109/300: 100%|██████████| 2/2 [00:00<00:00,  2.48batches/s, GPU_mem=2.39G, dloss=86.5, gloss=0.00915]
# Epoch 110/300: 100%|██████████| 2/2 [00:00<00:00,  2.54batches/s, GPU_mem=2.39G, dloss=87.1, gloss=0.00951]
# Epoch 111/300: 100%|██████████| 2/2 [00:00<00:00,  2.55batches/s, GPU_mem=2.39G, dloss=85.5, gloss=0.00904]
# Epoch 112/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=87.3, gloss=0.00922]
# Epoch 113/300: 100%|██████████| 2/2 [00:00<00:00,  2.48batches/s, GPU_mem=2.39G, dloss=88.6, gloss=0.00904]
# Epoch 114/300: 100%|██████████| 2/2 [00:00<00:00,  2.52batches/s, GPU_mem=2.39G, dloss=87.9, gloss=0.00942]
# Epoch 115/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=85.8, gloss=0.00907]
# Epoch 116/300: 100%|██████████| 2/2 [00:00<00:00,  2.47batches/s, GPU_mem=2.39G, dloss=87.9, gloss=0.00936]
# Epoch 117/300: 100%|██████████| 2/2 [00:00<00:00,  2.47batches/s, GPU_mem=2.39G, dloss=88.4, gloss=0.00924]
# Epoch 118/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=87, gloss=0.0091]
# Epoch 119/300: 100%|██████████| 2/2 [00:00<00:00,  2.47batches/s, GPU_mem=2.39G, dloss=87.9, gloss=0.00946]
# Epoch 120/300: 100%|██████████| 2/2 [00:00<00:00,  2.44batches/s, GPU_mem=2.39G, dloss=86.9, gloss=0.00982]
# Epoch 121/300: 100%|██████████| 2/2 [00:00<00:00,  2.47batches/s, GPU_mem=2.39G, dloss=84.7, gloss=0.00954]
# Epoch 122/300: 100%|██████████| 2/2 [00:00<00:00,  2.49batches/s, GPU_mem=2.39G, dloss=86.5, gloss=0.00923]
# Epoch 123/300: 100%|██████████| 2/2 [00:00<00:00,  2.22batches/s, GPU_mem=2.39G, dloss=86.8, gloss=0.00931]
# Epoch 124/300: 100%|██████████| 2/2 [00:00<00:00,  2.46batches/s, GPU_mem=2.39G, dloss=88.1, gloss=0.00938]
# Epoch 125/300: 100%|██████████| 2/2 [00:00<00:00,  2.45batches/s, GPU_mem=2.39G, dloss=89.2, gloss=0.00943]
# Epoch 126/300: 100%|██████████| 2/2 [00:00<00:00,  2.38batches/s, GPU_mem=2.39G, dloss=84.9, gloss=0.00949]
# Epoch 127/300: 100%|██████████| 2/2 [00:00<00:00,  2.47batches/s, GPU_mem=2.39G, dloss=87.3, gloss=0.00893]
# Epoch 128/300: 100%|██████████| 2/2 [00:00<00:00,  2.39batches/s, GPU_mem=2.39G, dloss=88.3, gloss=0.00899]
# Epoch 129/300: 100%|██████████| 2/2 [00:00<00:00,  2.42batches/s, GPU_mem=2.39G, dloss=87.7, gloss=0.00949]
# Epoch 130/300: 100%|██████████| 2/2 [00:00<00:00,  2.45batches/s, GPU_mem=2.39G, dloss=87.7, gloss=0.00909]
# Epoch 131/300: 100%|██████████| 2/2 [00:00<00:00,  2.43batches/s, GPU_mem=2.39G, dloss=87.6, gloss=0.00929]
# Epoch 132/300: 100%|██████████| 2/2 [00:00<00:00,  2.39batches/s, GPU_mem=2.39G, dloss=90.8, gloss=0.00936]
# Epoch 133/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=86.5, gloss=0.00916]
# Epoch 134/300: 100%|██████████| 2/2 [00:01<00:00,  1.73batches/s, GPU_mem=2.39G, dloss=85.8, gloss=0.00965]
# Epoch 135/300: 100%|██████████| 2/2 [00:01<00:00,  1.74batches/s, GPU_mem=2.39G, dloss=88.6, gloss=0.00885]
# Epoch 136/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=87.3, gloss=0.00879]
# Epoch 137/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=87.9, gloss=0.00918]
# Epoch 138/300: 100%|██████████| 2/2 [00:01<00:00,  1.74batches/s, GPU_mem=2.39G, dloss=86.8, gloss=0.00907]
# Epoch 139/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=86.7, gloss=0.00933]
# Epoch 140/300: 100%|██████████| 2/2 [00:01<00:00,  1.75batches/s, GPU_mem=2.39G, dloss=87.1, gloss=0.00858]
# Epoch 141/300: 100%|██████████| 2/2 [00:01<00:00,  1.83batches/s, GPU_mem=2.39G, dloss=87.9, gloss=0.0087]
# Epoch 142/300: 100%|██████████| 2/2 [00:01<00:00,  1.67batches/s, GPU_mem=2.39G, dloss=85.3, gloss=0.00906]
# Epoch 143/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=87, gloss=0.00911]
# Epoch 144/300: 100%|██████████| 2/2 [00:01<00:00,  1.72batches/s, GPU_mem=2.39G, dloss=88, gloss=0.009]
# Epoch 145/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=87.7, gloss=0.00898]
# Epoch 146/300: 100%|██████████| 2/2 [00:01<00:00,  1.84batches/s, GPU_mem=2.39G, dloss=90.3, gloss=0.00945]
# Epoch 147/300: 100%|██████████| 2/2 [00:01<00:00,  1.76batches/s, GPU_mem=2.39G, dloss=87.1, gloss=0.0092]
# Epoch 148/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=85.1, gloss=0.00904]
# Epoch 149/300: 100%|██████████| 2/2 [00:01<00:00,  1.62batches/s, GPU_mem=2.39G, dloss=87.1, gloss=0.00945]
# Epoch 150/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=88.8, gloss=0.00908]
# Epoch 151/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=89.2, gloss=0.00883]
# Epoch 152/300: 100%|██████████| 2/2 [00:01<00:00,  1.76batches/s, GPU_mem=2.39G, dloss=86.2, gloss=0.0095]
# Epoch 153/300: 100%|██████████| 2/2 [00:01<00:00,  1.71batches/s, GPU_mem=2.39G, dloss=88, gloss=0.00886]
# Epoch 154/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=86.6, gloss=0.00906]
# Epoch 155/300: 100%|██████████| 2/2 [00:01<00:00,  1.84batches/s, GPU_mem=2.39G, dloss=85.9, gloss=0.00938]
# Epoch 156/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=89.2, gloss=0.00906]
# Epoch 157/300: 100%|██████████| 2/2 [00:01<00:00,  1.83batches/s, GPU_mem=2.39G, dloss=88.9, gloss=0.00931]
# Epoch 158/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=82.3, gloss=0.00923]
# Epoch 159/300: 100%|██████████| 2/2 [00:01<00:00,  1.89batches/s, GPU_mem=2.39G, dloss=87.5, gloss=0.00936]
# Epoch 160/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=84.7, gloss=0.00906]
# Epoch 161/300: 100%|██████████| 2/2 [00:01<00:00,  1.69batches/s, GPU_mem=2.39G, dloss=87.1, gloss=0.00877]
# Epoch 162/300: 100%|██████████| 2/2 [00:01<00:00,  1.76batches/s, GPU_mem=2.39G, dloss=86.2, gloss=0.00925]
# Epoch 163/300: 100%|██████████| 2/2 [00:01<00:00,  1.66batches/s, GPU_mem=2.39G, dloss=87.5, gloss=0.00928]
# Epoch 164/300: 100%|██████████| 2/2 [00:01<00:00,  1.56batches/s, GPU_mem=2.39G, dloss=88.2, gloss=0.00917]
# Epoch 165/300: 100%|██████████| 2/2 [00:01<00:00,  1.69batches/s, GPU_mem=2.39G, dloss=85.6, gloss=0.009]
# Epoch 166/300: 100%|██████████| 2/2 [00:01<00:00,  1.73batches/s, GPU_mem=2.39G, dloss=86.1, gloss=0.00919]
# Epoch 167/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=85.1, gloss=0.00944]
# Epoch 168/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=88.8, gloss=0.00895]
# Epoch 169/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=83.4, gloss=0.00914]
# Epoch 170/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=87.1, gloss=0.00932]
# Epoch 171/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=87, gloss=0.00892]
# Epoch 172/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=87.2, gloss=0.00945]
# Epoch 173/300: 100%|██████████| 2/2 [00:01<00:00,  1.78batches/s, GPU_mem=2.39G, dloss=87.7, gloss=0.00918]
# Epoch 174/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=87, gloss=0.009]
# Epoch 175/300: 100%|██████████| 2/2 [00:01<00:00,  1.84batches/s, GPU_mem=2.39G, dloss=85, gloss=0.00946]
# Epoch 176/300: 100%|██████████| 2/2 [00:01<00:00,  1.76batches/s, GPU_mem=2.39G, dloss=87.5, gloss=0.0097]
# Epoch 177/300: 100%|██████████| 2/2 [00:01<00:00,  1.66batches/s, GPU_mem=2.39G, dloss=87.2, gloss=0.00906]
# Epoch 178/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=90, gloss=0.00923]
# Epoch 179/300: 100%|██████████| 2/2 [00:01<00:00,  1.78batches/s, GPU_mem=2.39G, dloss=87.9, gloss=0.00896]
# Epoch 180/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=87.8, gloss=0.00921]
# Epoch 181/300: 100%|██████████| 2/2 [00:01<00:00,  1.70batches/s, GPU_mem=2.39G, dloss=89.3, gloss=0.00933]
# Epoch 182/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=88, gloss=0.00934]
# Epoch 183/300: 100%|██████████| 2/2 [00:01<00:00,  1.76batches/s, GPU_mem=2.39G, dloss=88.5, gloss=0.00884]
# Epoch 184/300: 100%|██████████| 2/2 [00:01<00:00,  1.78batches/s, GPU_mem=2.39G, dloss=86.4, gloss=0.00915]
# Epoch 185/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=87.8, gloss=0.00914]
# Epoch 186/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=86.9, gloss=0.0094]
# Epoch 187/300: 100%|██████████| 2/2 [00:01<00:00,  1.71batches/s, GPU_mem=2.39G, dloss=88.6, gloss=0.0093]
# Epoch 188/300: 100%|██████████| 2/2 [00:01<00:00,  1.68batches/s, GPU_mem=2.39G, dloss=88.7, gloss=0.00892]
# Epoch 189/300: 100%|██████████| 2/2 [00:01<00:00,  1.64batches/s, GPU_mem=2.39G, dloss=88.2, gloss=0.00887]
# Epoch 190/300: 100%|██████████| 2/2 [00:01<00:00,  1.78batches/s, GPU_mem=2.39G, dloss=87.8, gloss=0.00906]
# Epoch 191/300: 100%|██████████| 2/2 [00:01<00:00,  1.76batches/s, GPU_mem=2.39G, dloss=87, gloss=0.00899]
# Epoch 192/300: 100%|██████████| 2/2 [00:01<00:00,  1.84batches/s, GPU_mem=2.39G, dloss=88.2, gloss=0.00869]
# Epoch 193/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=86.7, gloss=0.00925]
# Epoch 194/300: 100%|██████████| 2/2 [00:01<00:00,  1.78batches/s, GPU_mem=2.39G, dloss=87.1, gloss=0.00888]
# Epoch 195/300: 100%|██████████| 2/2 [00:01<00:00,  1.74batches/s, GPU_mem=2.39G, dloss=87.1, gloss=0.00927]
# Epoch 196/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=87.8, gloss=0.00901]
# Epoch 197/300: 100%|██████████| 2/2 [00:01<00:00,  1.65batches/s, GPU_mem=2.39G, dloss=88.8, gloss=0.00907]
# Epoch 198/300: 100%|██████████| 2/2 [00:01<00:00,  1.36batches/s, GPU_mem=2.39G, dloss=86.5, gloss=0.00898]
# Epoch 199/300: 100%|██████████| 2/2 [00:01<00:00,  1.27batches/s, GPU_mem=2.39G, dloss=88.6, gloss=0.0095]
# Epoch 200/300: 100%|██████████| 2/2 [01:15<00:00, 37.64s/batches, GPU_mem=2.39G, dloss=86.3, gloss=0.00869]
# Epoch 201/300: 100%|██████████| 2/2 [00:01<00:00,  1.55batches/s, GPU_mem=2.39G, dloss=87.7, gloss=0.00907]
# Epoch 202/300: 100%|██████████| 2/2 [00:01<00:00,  1.49batches/s, GPU_mem=2.39G, dloss=85.5, gloss=0.00928]
# Epoch 203/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=89, gloss=0.00966]
# Epoch 204/300: 100%|██████████| 2/2 [00:01<00:00,  1.58batches/s, GPU_mem=2.39G, dloss=85.4, gloss=0.00908]
# Epoch 205/300: 100%|██████████| 2/2 [00:01<00:00,  1.59batches/s, GPU_mem=2.39G, dloss=87.3, gloss=0.00927]
# Epoch 206/300: 100%|██████████| 2/2 [00:01<00:00,  1.60batches/s, GPU_mem=2.39G, dloss=88, gloss=0.00884]
# Epoch 207/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=87, gloss=0.00961]
# Epoch 208/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=88.2, gloss=0.0089]
# Epoch 209/300: 100%|██████████| 2/2 [00:01<00:00,  1.74batches/s, GPU_mem=2.39G, dloss=88.4, gloss=0.00948]
# Epoch 210/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=86.5, gloss=0.00909]
# Epoch 211/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=88.3, gloss=0.00891]
# Epoch 212/300: 100%|██████████| 2/2 [00:01<00:00,  1.87batches/s, GPU_mem=2.39G, dloss=87.6, gloss=0.00954]
# Epoch 213/300: 100%|██████████| 2/2 [00:01<00:00,  1.70batches/s, GPU_mem=2.39G, dloss=86.6, gloss=0.00913]
# Epoch 214/300: 100%|██████████| 2/2 [00:01<00:00,  1.88batches/s, GPU_mem=2.39G, dloss=87.7, gloss=0.00925]
# Epoch 215/300: 100%|██████████| 2/2 [00:01<00:00,  1.72batches/s, GPU_mem=2.39G, dloss=87.4, gloss=0.00965]
# Epoch 216/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=87.4, gloss=0.0091]
# Epoch 217/300: 100%|██████████| 2/2 [00:01<00:00,  1.66batches/s, GPU_mem=2.39G, dloss=87.6, gloss=0.00922]
# Epoch 218/300: 100%|██████████| 2/2 [00:01<00:00,  1.76batches/s, GPU_mem=2.39G, dloss=86.2, gloss=0.00919]
# Epoch 219/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=87.8, gloss=0.00896]
# Epoch 220/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=88.8, gloss=0.00935]
# Epoch 221/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=87.6, gloss=0.0091]
# Epoch 222/300: 100%|██████████| 2/2 [00:01<00:00,  1.72batches/s, GPU_mem=2.39G, dloss=87.7, gloss=0.00882]
# Epoch 223/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=88.9, gloss=0.00925]
# Epoch 224/300: 100%|██████████| 2/2 [00:01<00:00,  1.73batches/s, GPU_mem=2.39G, dloss=88.2, gloss=0.00922]
# Epoch 225/300: 100%|██████████| 2/2 [00:01<00:00,  1.73batches/s, GPU_mem=2.39G, dloss=88.7, gloss=0.00921]
# Epoch 226/300: 100%|██████████| 2/2 [00:01<00:00,  1.50batches/s, GPU_mem=2.39G, dloss=90.5, gloss=0.00911]
# Epoch 227/300: 100%|██████████| 2/2 [00:01<00:00,  1.78batches/s, GPU_mem=2.39G, dloss=87.5, gloss=0.00926]
# Epoch 228/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=88.1, gloss=0.00895]
# Epoch 229/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=87.1, gloss=0.00928]
# Epoch 230/300: 100%|██████████| 2/2 [00:01<00:00,  1.71batches/s, GPU_mem=2.39G, dloss=88.2, gloss=0.00915]
# Epoch 231/300: 100%|██████████| 2/2 [00:01<00:00,  1.75batches/s, GPU_mem=2.39G, dloss=88.2, gloss=0.00914]
# Epoch 232/300: 100%|██████████| 2/2 [00:01<00:00,  1.75batches/s, GPU_mem=2.39G, dloss=85.2, gloss=0.00904]
# Epoch 233/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=87.9, gloss=0.00905]
# Epoch 234/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=85.9, gloss=0.00972]
# Epoch 235/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=86.9, gloss=0.009]
# Epoch 236/300: 100%|██████████| 2/2 [00:01<00:00,  1.75batches/s, GPU_mem=2.39G, dloss=85, gloss=0.00891]
# Epoch 237/300: 100%|██████████| 2/2 [00:01<00:00,  1.83batches/s, GPU_mem=2.39G, dloss=88, gloss=0.00918]
# Epoch 238/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=88.2, gloss=0.00909]
# Epoch 239/300: 100%|██████████| 2/2 [00:01<00:00,  1.76batches/s, GPU_mem=2.39G, dloss=87.9, gloss=0.00888]
# Epoch 240/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=88.8, gloss=0.00955]
# Epoch 241/300: 100%|██████████| 2/2 [00:01<00:00,  1.88batches/s, GPU_mem=2.39G, dloss=86.8, gloss=0.00914]
# Epoch 242/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=87.7, gloss=0.00919]
# Epoch 243/300: 100%|██████████| 2/2 [00:01<00:00,  1.74batches/s, GPU_mem=2.39G, dloss=85.7, gloss=0.00905]
# Epoch 244/300: 100%|██████████| 2/2 [00:01<00:00,  1.71batches/s, GPU_mem=2.39G, dloss=86.5, gloss=0.00925]
# Epoch 245/300: 100%|██████████| 2/2 [00:01<00:00,  1.76batches/s, GPU_mem=2.39G, dloss=86.3, gloss=0.00901]
# Epoch 246/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=84.1, gloss=0.00871]
# Epoch 247/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=84.1, gloss=0.00917]
# Epoch 248/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=85.5, gloss=0.00954]
# Epoch 249/300: 100%|██████████| 2/2 [00:01<00:00,  1.61batches/s, GPU_mem=2.39G, dloss=88.4, gloss=0.00878]
# Epoch 250/300: 100%|██████████| 2/2 [00:01<00:00,  1.72batches/s, GPU_mem=2.39G, dloss=88.5, gloss=0.00907]
# Epoch 251/300: 100%|██████████| 2/2 [00:01<00:00,  1.78batches/s, GPU_mem=2.39G, dloss=86.9, gloss=0.00903]
# Epoch 252/300: 100%|██████████| 2/2 [00:01<00:00,  1.75batches/s, GPU_mem=2.39G, dloss=89.7, gloss=0.00898]
# Epoch 253/300: 100%|██████████| 2/2 [00:01<00:00,  1.57batches/s, GPU_mem=2.39G, dloss=87.6, gloss=0.00928]
# Epoch 254/300: 100%|██████████| 2/2 [00:01<00:00,  1.70batches/s, GPU_mem=2.39G, dloss=87.2, gloss=0.00954]
# Epoch 255/300: 100%|██████████| 2/2 [00:01<00:00,  1.72batches/s, GPU_mem=2.39G, dloss=85, gloss=0.00913]
# Epoch 256/300: 100%|██████████| 2/2 [00:01<00:00,  1.64batches/s, GPU_mem=2.39G, dloss=87.4, gloss=0.00918]
# Epoch 257/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=88.8, gloss=0.00898]
# Epoch 258/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=88.4, gloss=0.0088]
# Epoch 259/300: 100%|██████████| 2/2 [00:01<00:00,  1.57batches/s, GPU_mem=2.39G, dloss=87.5, gloss=0.00901]
# Epoch 260/300: 100%|██████████| 2/2 [00:01<00:00,  1.72batches/s, GPU_mem=2.39G, dloss=86.2, gloss=0.00882]
# Epoch 261/300: 100%|██████████| 2/2 [00:01<00:00,  1.71batches/s, GPU_mem=2.39G, dloss=89, gloss=0.00906]
# Epoch 262/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=88, gloss=0.0089]
# Epoch 263/300: 100%|██████████| 2/2 [00:00<00:00,  2.42batches/s, GPU_mem=2.39G, dloss=88.4, gloss=0.0092]
# Epoch 264/300: 100%|██████████| 2/2 [00:00<00:00,  2.32batches/s, GPU_mem=2.39G, dloss=87.4, gloss=0.00878]
# Epoch 265/300: 100%|██████████| 2/2 [00:00<00:00,  2.19batches/s, GPU_mem=2.39G, dloss=87.9, gloss=0.00915]
# Epoch 266/300: 100%|██████████| 2/2 [00:01<00:00,  1.91batches/s, GPU_mem=2.39G, dloss=87, gloss=0.00908]
# Epoch 267/300: 100%|██████████| 2/2 [00:00<00:00,  2.36batches/s, GPU_mem=2.39G, dloss=87.6, gloss=0.00924]
# Epoch 268/300: 100%|██████████| 2/2 [00:00<00:00,  2.38batches/s, GPU_mem=2.39G, dloss=85.7, gloss=0.00935]
# Epoch 269/300: 100%|██████████| 2/2 [00:00<00:00,  2.40batches/s, GPU_mem=2.39G, dloss=87.3, gloss=0.00906]
# Epoch 270/300: 100%|██████████| 2/2 [00:00<00:00,  2.34batches/s, GPU_mem=2.39G, dloss=86.6, gloss=0.00957]
# Epoch 271/300: 100%|██████████| 2/2 [00:00<00:00,  2.36batches/s, GPU_mem=2.39G, dloss=86.6, gloss=0.00914]
# Epoch 272/300: 100%|██████████| 2/2 [00:00<00:00,  2.39batches/s, GPU_mem=2.39G, dloss=87.2, gloss=0.00906]
# Epoch 273/300: 100%|██████████| 2/2 [00:00<00:00,  2.33batches/s, GPU_mem=2.39G, dloss=89.6, gloss=0.00935]
# Epoch 274/300: 100%|██████████| 2/2 [00:00<00:00,  2.33batches/s, GPU_mem=2.39G, dloss=87.2, gloss=0.0094]
# Epoch 275/300: 100%|██████████| 2/2 [00:00<00:00,  2.24batches/s, GPU_mem=2.39G, dloss=87.3, gloss=0.00908]
# Epoch 276/300: 100%|██████████| 2/2 [00:00<00:00,  2.15batches/s, GPU_mem=2.39G, dloss=87.9, gloss=0.00898]
# Epoch 277/300: 100%|██████████| 2/2 [00:00<00:00,  2.36batches/s, GPU_mem=2.39G, dloss=86.9, gloss=0.00905]
# Epoch 278/300: 100%|██████████| 2/2 [00:00<00:00,  2.37batches/s, GPU_mem=2.39G, dloss=86, gloss=0.00934]
# Epoch 279/300: 100%|██████████| 2/2 [00:00<00:00,  2.38batches/s, GPU_mem=2.39G, dloss=88.3, gloss=0.00909]
# Epoch 280/300: 100%|██████████| 2/2 [00:00<00:00,  2.43batches/s, GPU_mem=2.39G, dloss=86.9, gloss=0.00895]
# Epoch 281/300: 100%|██████████| 2/2 [00:00<00:00,  2.36batches/s, GPU_mem=2.39G, dloss=87.9, gloss=0.00908]
# Epoch 282/300: 100%|██████████| 2/2 [00:00<00:00,  2.36batches/s, GPU_mem=2.39G, dloss=89.3, gloss=0.00978]
# Epoch 283/300: 100%|██████████| 2/2 [00:00<00:00,  2.39batches/s, GPU_mem=2.39G, dloss=87, gloss=0.00917]
# Epoch 284/300: 100%|██████████| 2/2 [00:00<00:00,  2.40batches/s, GPU_mem=2.39G, dloss=87.4, gloss=0.00901]
# Epoch 285/300: 100%|██████████| 2/2 [00:00<00:00,  2.43batches/s, GPU_mem=2.39G, dloss=88.3, gloss=0.00923]
# Epoch 286/300: 100%|██████████| 2/2 [00:00<00:00,  2.36batches/s, GPU_mem=2.39G, dloss=85.4, gloss=0.00908]
# Epoch 287/300: 100%|██████████| 2/2 [00:00<00:00,  2.38batches/s, GPU_mem=2.39G, dloss=88.7, gloss=0.00909]
# Epoch 288/300: 100%|██████████| 2/2 [00:00<00:00,  2.40batches/s, GPU_mem=2.39G, dloss=86.3, gloss=0.00912]
# Epoch 289/300: 100%|██████████| 2/2 [00:00<00:00,  2.41batches/s, GPU_mem=2.39G, dloss=89.1, gloss=0.00901]
# Epoch 290/300: 100%|██████████| 2/2 [00:00<00:00,  2.37batches/s, GPU_mem=2.39G, dloss=85.3, gloss=0.00911]
# Epoch 291/300: 100%|██████████| 2/2 [00:00<00:00,  2.44batches/s, GPU_mem=2.39G, dloss=86.7, gloss=0.00928]
# Epoch 292/300: 100%|██████████| 2/2 [00:00<00:00,  2.36batches/s, GPU_mem=2.39G, dloss=87.8, gloss=0.00912]
# Epoch 293/300: 100%|██████████| 2/2 [00:00<00:00,  2.43batches/s, GPU_mem=2.39G, dloss=87.6, gloss=0.00912]
# Epoch 294/300: 100%|██████████| 2/2 [00:00<00:00,  2.41batches/s, GPU_mem=2.39G, dloss=88.1, gloss=0.00921]
# Epoch 295/300: 100%|██████████| 2/2 [00:00<00:00,  2.39batches/s, GPU_mem=2.39G, dloss=89.4, gloss=0.00944]
# Epoch 296/300: 100%|██████████| 2/2 [00:00<00:00,  2.48batches/s, GPU_mem=2.39G, dloss=87.2, gloss=0.00972]
# Epoch 297/300: 100%|██████████| 2/2 [00:00<00:00,  2.44batches/s, GPU_mem=2.39G, dloss=88.5, gloss=0.00935]
# Epoch 298/300: 100%|██████████| 2/2 [00:00<00:00,  2.41batches/s, GPU_mem=2.39G, dloss=89.3, gloss=0.00894]
# Epoch 299/300: 100%|██████████| 2/2 [00:00<00:00,  2.46batches/s, GPU_mem=2.39G, dloss=89, gloss=0.00938]

# %% [markdown]
# # Test

# %%
ckpt = torch.load('srgan.pt')
test_generator = ckpt['generator'].to(device).float()
test_generator.eval()
test_loader = LoadImages('data/test')  # test dataset: Set5

# %%
with torch.no_grad():
    for image, image_name in test_loader:
        image = image.to(device)
        pred = test_generator(image).cpu()
        pred_img = transforms.ToPILImage()(pred.squeeze(0))

        pred_img.save(f'output/srgan/srgan_{image_name}')
