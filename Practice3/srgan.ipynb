# %%
import os
from copy import deepcopy
from math import sqrt

import torch
import torchvision
import torch.nn as nn
from PIL import Image
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm

from models.srgan import Generator, Discriminator

# %%
SCALE_FACTOR = 4
CROP_SIZE = 32
IMG_FORMATS = 'bmp', 'dng', 'jpeg', 'jpg', 'mpo', 'png', 'tif', 'tiff', 'webp', 'pfm'  # include image suffixes

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# Total Variation Loss
class TVLoss(nn.Module):
    def __init__(self, tv_loss_weight=1):
        super(TVLoss, self).__init__()
        self.tv_loss_weight = tv_loss_weight

    def forward(self, x):
        batch_size = x.size()[0]
        h_x = x.size()[2]
        w_x = x.size()[3]
        count_h = self.tensor_size(x[:, :, 1:, :])
        count_w = self.tensor_size(x[:, :, :, 1:])
        h_tv = torch.pow((x[:, :, 1:, :] - x[:, :, :h_x - 1, :]), 2).sum()
        w_tv = torch.pow((x[:, :, :, 1:] - x[:, :, :, :w_x - 1]), 2).sum()
        return self.tv_loss_weight * 2 * (h_tv / count_h + w_tv / count_w) / batch_size

    @staticmethod
    def tensor_size(t):
        return t.size()[1] * t.size()[2] * t.size()[3]

# %%
class GeneratorLoss(nn.Module):
    def __init__(self):
        super().__init__()
        vgg = torchvision.models.vgg.vgg16(weights='VGG16_Weights.IMAGENET1K_V1')
        loss_net = nn.Sequential(*list(vgg.features)[:31]).eval()
        for param in loss_net.parameters():
            param.requires_grad = False
        self.loss_net = loss_net.to(device)
        self.mse_loss = nn.MSELoss()
        self.tv_loss = TVLoss()

    def forward(self, fakes, p, targets):
        # p: (G)fakes: fake_images, (D)probabilities of real_images, targets: target_images(high-resolution)
        image_loss = self.mse_loss(fakes, targets)  # Image Loss
        adversarial_loss = torch.mean(1 - p)  # Adversarial Loss
        perception_loss = self.mse_loss(self.loss_net(fakes), self.loss_net(targets))  # Perception Loss
        tv_loss = self.tv_loss(fakes)  # TV Loss

        return image_loss + 0.001 * adversarial_loss + 0.006 * perception_loss + 2e-8 * tv_loss

# %%
class DiscriminatorLoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.bce_loss = nn.BCELoss()

    def forward(self, p, p_gt):
        # p: probability of real_image, p_gt: probability(ground truth) of real_image
        return self.bce_loss(p, torch.zeros_like(p, device=device)) + self.bce_loss(p_gt, torch.ones_like(p_gt, device=device))

# %%
# train_dataset
class LoadDataset(Dataset):
    def __init__(self, path, scale_factor=SCALE_FACTOR, crop_size=CROP_SIZE):
        super().__init__()
        scale_resize = int(sqrt(scale_factor))
        crop_size_ = crop_size - (crop_size % scale_resize) # Valid crop size

        self.imgs_path_list = [os.path.join(path, x) for x in os.listdir(path) if x.split('.')[-1].lower() in IMG_FORMATS]

        self.image_transform = transforms.Compose([
            transforms.CenterCrop(crop_size_),
            transforms.Resize(crop_size_ // scale_resize, interpolation=Image.BICUBIC),
            transforms.ToTensor(),
        ])

        self.label_transform = transforms.Compose([
            transforms.CenterCrop(crop_size_),
            transforms.ToTensor(),
        ])

    def __len__(self):
        return len(self.imgs_path_list)

    def __getitem__(self, index):
        img = Image.open(self.imgs_path_list[index])
        label = img.copy()

        img = self.image_transform(img)
        label = self.label_transform(label)
        return img, label

# %%
# test_dataloader
class LoadImages:
    def __init__(self, path, scale_factor=SCALE_FACTOR):
        self.scale_factor = scale_factor
        self.scale_resize = int(sqrt(scale_factor))
        self.imgs_path_list = [os.path.join(path, x) for x in os.listdir(path) if x.split('.')[-1].lower() in IMG_FORMATS]
        self.num_files = len(self.imgs_path_list)

    def __len__(self):
        return self.num_files

    def __iter__(self):
        self.count = 0
        return self

    def __next__(self):
        if self.count == self.num_files:
            raise StopIteration
        img_path = self.imgs_path_list[self.count]
        self.count += 1

        img_name = img_path.split(os.sep)[-1]
        img0 = Image.open(img_path)
        img = img0.resize((
            int(img0.size[0] / self.scale_resize),
            int(img0.size[1] / self.scale_resize)
        ),
            Image.BICUBIC,  # scale the image via bicubic interpolation
        )

        img_ = transforms.ToTensor()(img).view(1, -1, img.size[1], img.size[0])

        return img_, img_name

# %% [markdown]
# # Train

# %%
train_generator = Generator(in_channels=3, scale_factor=SCALE_FACTOR).to(device)
train_discriminator = Discriminator(in_channels=3).to(device)

optimizerG = torch.optim.Adam(train_generator.parameters(), lr=1e-4)
optimizerD = torch.optim.Adam(train_discriminator.parameters(), lr=1e-3)

gloss_fn = GeneratorLoss()
dloss_fn = DiscriminatorLoss()

train_dataset = LoadDataset('data/train')
train_loader = DataLoader(dataset=train_dataset, batch_size=256, shuffle=True, num_workers=0)

# %%
epochs = 300
for epoch in range(epochs):
    train_generator.train()
    train_discriminator.train()
    mloss = torch.zeros(2, device=device)  # mean_loss of generator and discriminator

    pbar = tqdm(enumerate(train_loader), total=len(train_loader), desc=f'Epoch {epoch}/{epochs}', unit='batches')
    for i, (images, targets) in pbar:
        images, targets = images.to(device), targets.to(device)  # images: low_resolution, targets: high-resolution
        fakes = train_generator(images)  # fake_images
        ps = train_discriminator(fakes)  # probabilities of real_images
        ps_gt = train_discriminator(targets)  # probabilities(ground truth) of real_images

        gloss = gloss_fn(fakes, ps, targets)
        optimizerG.zero_grad()
        gloss.backward()
        optimizerG.step()

        dloss = dloss_fn(ps.detach(), ps_gt)
        optimizerD.zero_grad()
        dloss.backward()
        optimizerD.step()

        mloss[0] = (mloss[0] * i + gloss) / (i + 1)  # mean_loss of generator
        mloss[1] = (mloss[1] * i + dloss) / (i + 1)  # mean_loss of discriminator
        mem = f'{torch.cuda.memory_reserved() / 1e9 if torch.cuda.is_available() else 0:.3g}G'  # GPU_mem
        pbar.set_postfix(gloss=mloss[0].item(), dloss=mloss[1].item(), GPU_mem=mem)

    ckpt = {  # checkpoint
        'epoch': epoch,
        'generator': deepcopy(train_generator).half(),
        'discriminator': deepcopy(train_discriminator).half(),
        'optimizerG': optimizerG.state_dict(),
        'optimizerD': optimizerD.state_dict(),
    }
    torch.save(ckpt, 'srgan.pt')
# Out:
# Epoch 0/300: 100%|██████████| 2/2 [00:04<00:00,  2.18s/batches, GPU_mem=2.39G, dloss=1.67, gloss=0.114]
# Epoch 1/300: 100%|██████████| 2/2 [00:01<00:00,  1.65batches/s, GPU_mem=2.39G, dloss=3.93, gloss=0.0613]
# Epoch 2/300: 100%|██████████| 2/2 [00:01<00:00,  1.96batches/s, GPU_mem=2.39G, dloss=6.53, gloss=0.0433]
# Epoch 3/300: 100%|██████████| 2/2 [00:01<00:00,  1.93batches/s, GPU_mem=2.39G, dloss=8.72, gloss=0.0378]
# Epoch 4/300: 100%|██████████| 2/2 [00:01<00:00,  1.73batches/s, GPU_mem=2.39G, dloss=10.5, gloss=0.0331]
# Epoch 5/300: 100%|██████████| 2/2 [00:01<00:00,  1.92batches/s, GPU_mem=2.39G, dloss=14.7, gloss=0.0307]
# Epoch 6/300: 100%|██████████| 2/2 [00:01<00:00,  1.89batches/s, GPU_mem=2.39G, dloss=21.8, gloss=0.0284]
# Epoch 7/300: 100%|██████████| 2/2 [00:01<00:00,  1.88batches/s, GPU_mem=2.39G, dloss=33.4, gloss=0.0265]
# Epoch 8/300: 100%|██████████| 2/2 [00:01<00:00,  1.78batches/s, GPU_mem=2.39G, dloss=39.6, gloss=0.0246]
# Epoch 9/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=46.2, gloss=0.0221]
# Epoch 10/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=56.3, gloss=0.0219]
# Epoch 11/300: 100%|██████████| 2/2 [00:01<00:00,  1.86batches/s, GPU_mem=2.39G, dloss=59.1, gloss=0.0207]
# Epoch 12/300: 100%|██████████| 2/2 [00:01<00:00,  1.88batches/s, GPU_mem=2.39G, dloss=64.5, gloss=0.0192]
# Epoch 13/300: 100%|██████████| 2/2 [00:01<00:00,  1.91batches/s, GPU_mem=2.39G, dloss=65, gloss=0.0188]
# Epoch 14/300: 100%|██████████| 2/2 [00:01<00:00,  1.94batches/s, GPU_mem=2.39G, dloss=68.3, gloss=0.0177]
# Epoch 15/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=69.4, gloss=0.017]
# Epoch 16/300: 100%|██████████| 2/2 [00:01<00:00,  1.78batches/s, GPU_mem=2.39G, dloss=70.3, gloss=0.0166]
# Epoch 17/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=71.7, gloss=0.0167]
# Epoch 18/300: 100%|██████████| 2/2 [00:01<00:00,  1.84batches/s, GPU_mem=2.39G, dloss=72.2, gloss=0.0158]
# Epoch 19/300: 100%|██████████| 2/2 [00:01<00:00,  1.86batches/s, GPU_mem=2.39G, dloss=75.3, gloss=0.0149]
# Epoch 20/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=75.9, gloss=0.0154]
# Epoch 21/300: 100%|██████████| 2/2 [00:01<00:00,  1.96batches/s, GPU_mem=2.39G, dloss=75.3, gloss=0.0144]
# Epoch 22/300: 100%|██████████| 2/2 [00:01<00:00,  1.88batches/s, GPU_mem=2.39G, dloss=75.6, gloss=0.0139]
# Epoch 23/300: 100%|██████████| 2/2 [00:01<00:00,  1.97batches/s, GPU_mem=2.39G, dloss=77.9, gloss=0.0137]
# Epoch 24/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=78.1, gloss=0.0133]
# Epoch 25/300: 100%|██████████| 2/2 [00:01<00:00,  1.69batches/s, GPU_mem=2.39G, dloss=78.5, gloss=0.0133]
# Epoch 26/300: 100%|██████████| 2/2 [00:01<00:00,  1.91batches/s, GPU_mem=2.39G, dloss=77.4, gloss=0.0129]
# Epoch 27/300: 100%|██████████| 2/2 [00:01<00:00,  1.86batches/s, GPU_mem=2.39G, dloss=80.3, gloss=0.0124]
# Epoch 28/300: 100%|██████████| 2/2 [00:01<00:00,  1.97batches/s, GPU_mem=2.39G, dloss=78.3, gloss=0.0127]
# Epoch 29/300: 100%|██████████| 2/2 [00:00<00:00,  2.16batches/s, GPU_mem=2.39G, dloss=78.6, gloss=0.0126]
# Epoch 30/300: 100%|██████████| 2/2 [00:01<00:00,  1.93batches/s, GPU_mem=2.39G, dloss=78, gloss=0.0121]
# Epoch 31/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=79.3, gloss=0.0119]
# Epoch 32/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=81, gloss=0.0119]
# Epoch 33/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=79.7, gloss=0.0115]
# Epoch 34/300: 100%|██████████| 2/2 [00:01<00:00,  1.89batches/s, GPU_mem=2.39G, dloss=80, gloss=0.0114]
# Epoch 35/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=80.4, gloss=0.0112]
# Epoch 36/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=80.3, gloss=0.011]
# Epoch 37/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=79.7, gloss=0.0106]
# Epoch 38/300: 100%|██████████| 2/2 [00:01<00:00,  1.88batches/s, GPU_mem=2.39G, dloss=79.3, gloss=0.0107]
# Epoch 39/300: 100%|██████████| 2/2 [00:01<00:00,  1.88batches/s, GPU_mem=2.39G, dloss=80.3, gloss=0.0106]
# Epoch 40/300: 100%|██████████| 2/2 [00:01<00:00,  1.83batches/s, GPU_mem=2.39G, dloss=82.3, gloss=0.0104]
# Epoch 41/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=81.8, gloss=0.0101]
# Epoch 42/300: 100%|██████████| 2/2 [00:01<00:00,  1.96batches/s, GPU_mem=2.39G, dloss=78.5, gloss=0.0103]
# Epoch 43/300: 100%|██████████| 2/2 [00:01<00:00,  1.84batches/s, GPU_mem=2.39G, dloss=81.8, gloss=0.00994]
# Epoch 44/300: 100%|██████████| 2/2 [00:01<00:00,  1.88batches/s, GPU_mem=2.39G, dloss=81.6, gloss=0.0101]
# Epoch 45/300: 100%|██████████| 2/2 [00:00<00:00,  2.41batches/s, GPU_mem=2.39G, dloss=81.4, gloss=0.0103]
# Epoch 46/300: 100%|██████████| 2/2 [00:00<00:00,  2.50batches/s, GPU_mem=2.39G, dloss=78.2, gloss=0.00938]
# Epoch 47/300: 100%|██████████| 2/2 [00:00<00:00,  2.48batches/s, GPU_mem=2.39G, dloss=80.6, gloss=0.00947]
# Epoch 48/300: 100%|██████████| 2/2 [00:00<00:00,  2.40batches/s, GPU_mem=2.39G, dloss=81.5, gloss=0.00905]
# Epoch 49/300: 100%|██████████| 2/2 [00:00<00:00,  2.39batches/s, GPU_mem=2.39G, dloss=80.4, gloss=0.00866]
# Epoch 50/300: 100%|██████████| 2/2 [00:00<00:00,  2.47batches/s, GPU_mem=2.39G, dloss=78.3, gloss=0.00918]
# Epoch 51/300: 100%|██████████| 2/2 [00:00<00:00,  2.56batches/s, GPU_mem=2.39G, dloss=80.4, gloss=0.00853]
# Epoch 52/300: 100%|██████████| 2/2 [00:00<00:00,  2.52batches/s, GPU_mem=2.39G, dloss=81, gloss=0.00911]
# Epoch 53/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=79.7, gloss=0.00844]
# Epoch 54/300: 100%|██████████| 2/2 [00:00<00:00,  2.52batches/s, GPU_mem=2.39G, dloss=80.1, gloss=0.00941]
# Epoch 55/300: 100%|██████████| 2/2 [00:00<00:00,  2.45batches/s, GPU_mem=2.39G, dloss=81, gloss=0.00842]
# Epoch 56/300: 100%|██████████| 2/2 [00:00<00:00,  2.52batches/s, GPU_mem=2.39G, dloss=80.3, gloss=0.0081]
# Epoch 57/300: 100%|██████████| 2/2 [00:00<00:00,  2.52batches/s, GPU_mem=2.39G, dloss=79.9, gloss=0.00799]
# Epoch 58/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=79.6, gloss=0.00826]
# Epoch 59/300: 100%|██████████| 2/2 [00:00<00:00,  2.57batches/s, GPU_mem=2.39G, dloss=79.4, gloss=0.00829]
# Epoch 60/300: 100%|██████████| 2/2 [00:00<00:00,  2.51batches/s, GPU_mem=2.39G, dloss=80.6, gloss=0.00814]
# Epoch 61/300: 100%|██████████| 2/2 [00:00<00:00,  2.54batches/s, GPU_mem=2.39G, dloss=81.2, gloss=0.00779]
# Epoch 62/300: 100%|██████████| 2/2 [00:00<00:00,  2.54batches/s, GPU_mem=2.39G, dloss=80.3, gloss=0.00778]
# Epoch 63/300: 100%|██████████| 2/2 [00:00<00:00,  2.42batches/s, GPU_mem=2.39G, dloss=82.1, gloss=0.00789]
# Epoch 64/300: 100%|██████████| 2/2 [00:00<00:00,  2.44batches/s, GPU_mem=2.39G, dloss=81.4, gloss=0.00767]
# Epoch 65/300: 100%|██████████| 2/2 [00:00<00:00,  2.52batches/s, GPU_mem=2.39G, dloss=80.2, gloss=0.00777]
# Epoch 66/300: 100%|██████████| 2/2 [00:00<00:00,  2.54batches/s, GPU_mem=2.39G, dloss=78.4, gloss=0.008]
# Epoch 67/300: 100%|██████████| 2/2 [00:00<00:00,  2.52batches/s, GPU_mem=2.39G, dloss=79.9, gloss=0.00764]
# Epoch 68/300: 100%|██████████| 2/2 [00:00<00:00,  2.50batches/s, GPU_mem=2.39G, dloss=81.5, gloss=0.00792]
# Epoch 69/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=80.3, gloss=0.00711]
# Epoch 70/300: 100%|██████████| 2/2 [00:00<00:00,  2.52batches/s, GPU_mem=2.39G, dloss=79.8, gloss=0.00723]
# Epoch 71/300: 100%|██████████| 2/2 [00:00<00:00,  2.44batches/s, GPU_mem=2.39G, dloss=80.6, gloss=0.00717]
# Epoch 72/300: 100%|██████████| 2/2 [00:00<00:00,  2.43batches/s, GPU_mem=2.39G, dloss=81.2, gloss=0.00722]
# Epoch 73/300: 100%|██████████| 2/2 [00:00<00:00,  2.51batches/s, GPU_mem=2.39G, dloss=80.1, gloss=0.00709]
# Epoch 74/300: 100%|██████████| 2/2 [00:00<00:00,  2.51batches/s, GPU_mem=2.39G, dloss=81.9, gloss=0.00704]
# Epoch 75/300: 100%|██████████| 2/2 [00:00<00:00,  2.46batches/s, GPU_mem=2.39G, dloss=82.7, gloss=0.0067]
# Epoch 76/300: 100%|██████████| 2/2 [00:00<00:00,  2.41batches/s, GPU_mem=2.39G, dloss=82.6, gloss=0.00692]
# Epoch 77/300: 100%|██████████| 2/2 [00:00<00:00,  2.56batches/s, GPU_mem=2.39G, dloss=79, gloss=0.00685]
# Epoch 78/300: 100%|██████████| 2/2 [00:00<00:00,  2.51batches/s, GPU_mem=2.39G, dloss=79, gloss=0.00672]
# Epoch 79/300: 100%|██████████| 2/2 [00:00<00:00,  2.51batches/s, GPU_mem=2.39G, dloss=79.6, gloss=0.00706]
# Epoch 80/300: 100%|██████████| 2/2 [00:00<00:00,  2.52batches/s, GPU_mem=2.39G, dloss=82.3, gloss=0.00679]
# Epoch 81/300: 100%|██████████| 2/2 [00:00<00:00,  2.52batches/s, GPU_mem=2.39G, dloss=82, gloss=0.00731]
# Epoch 82/300: 100%|██████████| 2/2 [00:00<00:00,  2.49batches/s, GPU_mem=2.39G, dloss=82.2, gloss=0.00663]
# Epoch 83/300: 100%|██████████| 2/2 [00:00<00:00,  2.50batches/s, GPU_mem=2.39G, dloss=82.7, gloss=0.00649]
# Epoch 84/300: 100%|██████████| 2/2 [00:00<00:00,  2.49batches/s, GPU_mem=2.39G, dloss=80.6, gloss=0.00675]
# Epoch 85/300: 100%|██████████| 2/2 [00:00<00:00,  2.57batches/s, GPU_mem=2.39G, dloss=81.4, gloss=0.00651]
# Epoch 86/300: 100%|██████████| 2/2 [00:00<00:00,  2.51batches/s, GPU_mem=2.39G, dloss=83, gloss=0.00665]
# Epoch 87/300: 100%|██████████| 2/2 [00:00<00:00,  2.52batches/s, GPU_mem=2.39G, dloss=82.6, gloss=0.00681]
# Epoch 88/300: 100%|██████████| 2/2 [00:00<00:00,  2.56batches/s, GPU_mem=2.39G, dloss=80, gloss=0.00702]
# Epoch 89/300: 100%|██████████| 2/2 [00:00<00:00,  2.50batches/s, GPU_mem=2.39G, dloss=82.8, gloss=0.0067]
# Epoch 90/300: 100%|██████████| 2/2 [00:00<00:00,  2.50batches/s, GPU_mem=2.39G, dloss=82.7, gloss=0.00686]
# Epoch 91/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=80.9, gloss=0.00631]
# Epoch 92/300: 100%|██████████| 2/2 [00:00<00:00,  2.46batches/s, GPU_mem=2.39G, dloss=81.2, gloss=0.00604]
# Epoch 93/300: 100%|██████████| 2/2 [00:00<00:00,  2.38batches/s, GPU_mem=2.39G, dloss=81.9, gloss=0.00624]
# Epoch 94/300: 100%|██████████| 2/2 [00:00<00:00,  2.49batches/s, GPU_mem=2.39G, dloss=80.1, gloss=0.00602]
# Epoch 95/300: 100%|██████████| 2/2 [00:00<00:00,  2.45batches/s, GPU_mem=2.39G, dloss=81.6, gloss=0.00624]
# Epoch 96/300: 100%|██████████| 2/2 [00:00<00:00,  2.47batches/s, GPU_mem=2.39G, dloss=80.6, gloss=0.00627]
# Epoch 97/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=78.6, gloss=0.00597]
# Epoch 98/300: 100%|██████████| 2/2 [00:00<00:00,  2.51batches/s, GPU_mem=2.39G, dloss=81.6, gloss=0.00619]
# Epoch 99/300: 100%|██████████| 2/2 [00:00<00:00,  2.50batches/s, GPU_mem=2.39G, dloss=80.8, gloss=0.00589]
# Epoch 100/300: 100%|██████████| 2/2 [00:00<00:00,  2.41batches/s, GPU_mem=2.39G, dloss=81.8, gloss=0.00584]
# Epoch 101/300: 100%|██████████| 2/2 [00:00<00:00,  2.34batches/s, GPU_mem=2.39G, dloss=80.2, gloss=0.00587]
# Epoch 102/300: 100%|██████████| 2/2 [00:00<00:00,  2.31batches/s, GPU_mem=2.39G, dloss=82.7, gloss=0.00582]
# Epoch 103/300: 100%|██████████| 2/2 [00:00<00:00,  2.46batches/s, GPU_mem=2.39G, dloss=82.6, gloss=0.00596]
# Epoch 104/300: 100%|██████████| 2/2 [00:00<00:00,  2.53batches/s, GPU_mem=2.39G, dloss=82.2, gloss=0.00616]
# Epoch 105/300: 100%|██████████| 2/2 [00:00<00:00,  2.45batches/s, GPU_mem=2.39G, dloss=80.7, gloss=0.00581]
# Epoch 106/300: 100%|██████████| 2/2 [00:00<00:00,  2.15batches/s, GPU_mem=2.39G, dloss=82.7, gloss=0.00576]
# Epoch 107/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=82, gloss=0.00581]
# Epoch 108/300: 100%|██████████| 2/2 [00:01<00:00,  1.87batches/s, GPU_mem=2.39G, dloss=82.8, gloss=0.00603]
# Epoch 109/300: 100%|██████████| 2/2 [00:01<00:00,  1.87batches/s, GPU_mem=2.39G, dloss=81, gloss=0.00598]
# Epoch 110/300: 100%|██████████| 2/2 [00:01<00:00,  1.83batches/s, GPU_mem=2.39G, dloss=81.8, gloss=0.00585]
# Epoch 111/300: 100%|██████████| 2/2 [00:01<00:00,  1.90batches/s, GPU_mem=2.39G, dloss=82.8, gloss=0.00586]
# Epoch 112/300: 100%|██████████| 2/2 [00:01<00:00,  1.71batches/s, GPU_mem=2.39G, dloss=81.2, gloss=0.00607]
# Epoch 113/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=82.4, gloss=0.00594]
# Epoch 114/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=83.1, gloss=0.00557]
# Epoch 115/300: 100%|██████████| 2/2 [00:01<00:00,  1.59batches/s, GPU_mem=2.39G, dloss=80.2, gloss=0.00552]
# Epoch 116/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=79.9, gloss=0.00554]
# Epoch 117/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=82, gloss=0.00592]
# Epoch 118/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=80.5, gloss=0.0058]
# Epoch 119/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=82.3, gloss=0.00534]
# Epoch 120/300: 100%|██████████| 2/2 [00:01<00:00,  1.86batches/s, GPU_mem=2.39G, dloss=83.8, gloss=0.00552]
# Epoch 121/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=83.9, gloss=0.00559]
# Epoch 122/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=83.3, gloss=0.00577]
# Epoch 123/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=81.8, gloss=0.00533]
# Epoch 124/300: 100%|██████████| 2/2 [00:01<00:00,  1.60batches/s, GPU_mem=2.39G, dloss=84.2, gloss=0.00541]
# Epoch 125/300: 100%|██████████| 2/2 [00:01<00:00,  1.68batches/s, GPU_mem=2.39G, dloss=81.1, gloss=0.00534]
# Epoch 126/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=82.9, gloss=0.00517]
# Epoch 127/300: 100%|██████████| 2/2 [00:01<00:00,  1.76batches/s, GPU_mem=2.39G, dloss=82.7, gloss=0.00553]
# Epoch 128/300: 100%|██████████| 2/2 [00:01<00:00,  1.78batches/s, GPU_mem=2.39G, dloss=83.4, gloss=0.00607]
# Epoch 129/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=81.5, gloss=0.00539]
# Epoch 130/300: 100%|██████████| 2/2 [00:01<00:00,  1.83batches/s, GPU_mem=2.39G, dloss=82.8, gloss=0.00554]
# Epoch 131/300: 100%|██████████| 2/2 [00:01<00:00,  1.73batches/s, GPU_mem=2.39G, dloss=83.7, gloss=0.00536]
# Epoch 132/300: 100%|██████████| 2/2 [00:01<00:00,  1.96batches/s, GPU_mem=2.39G, dloss=82.9, gloss=0.00523]
# Epoch 133/300: 100%|██████████| 2/2 [00:01<00:00,  1.92batches/s, GPU_mem=2.39G, dloss=80.8, gloss=0.00523]
# Epoch 134/300: 100%|██████████| 2/2 [00:01<00:00,  1.83batches/s, GPU_mem=2.39G, dloss=83, gloss=0.00517]
# Epoch 135/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=80.6, gloss=0.00506]
# Epoch 136/300: 100%|██████████| 2/2 [00:01<00:00,  1.78batches/s, GPU_mem=2.39G, dloss=83, gloss=0.00558]
# Epoch 137/300: 100%|██████████| 2/2 [00:01<00:00,  1.83batches/s, GPU_mem=2.39G, dloss=82.4, gloss=0.00497]
# Epoch 138/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=85.1, gloss=0.00598]
# Epoch 139/300: 100%|██████████| 2/2 [00:01<00:00,  1.74batches/s, GPU_mem=2.39G, dloss=83.8, gloss=0.00513]
# Epoch 140/300: 100%|██████████| 2/2 [00:01<00:00,  1.68batches/s, GPU_mem=2.39G, dloss=83.8, gloss=0.00508]
# Epoch 141/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=82.3, gloss=0.00504]
# Epoch 142/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=83.3, gloss=0.00496]
# Epoch 143/300: 100%|██████████| 2/2 [00:01<00:00,  1.89batches/s, GPU_mem=2.39G, dloss=83.3, gloss=0.00501]
# Epoch 144/300: 100%|██████████| 2/2 [00:01<00:00,  1.89batches/s, GPU_mem=2.39G, dloss=82.5, gloss=0.00487]
# Epoch 145/300: 100%|██████████| 2/2 [00:01<00:00,  1.86batches/s, GPU_mem=2.39G, dloss=83.2, gloss=0.00515]
# Epoch 146/300: 100%|██████████| 2/2 [00:01<00:00,  1.74batches/s, GPU_mem=2.39G, dloss=83.7, gloss=0.00484]
# Epoch 147/300: 100%|██████████| 2/2 [00:01<00:00,  1.87batches/s, GPU_mem=2.39G, dloss=83.4, gloss=0.00482]
# Epoch 148/300: 100%|██████████| 2/2 [00:01<00:00,  1.72batches/s, GPU_mem=2.39G, dloss=83.5, gloss=0.00501]
# Epoch 149/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=82.1, gloss=0.00488]
# Epoch 150/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=82.2, gloss=0.00495]
# Epoch 151/300: 100%|██████████| 2/2 [00:01<00:00,  1.96batches/s, GPU_mem=2.39G, dloss=83.6, gloss=0.00464]
# Epoch 152/300: 100%|██████████| 2/2 [00:01<00:00,  1.90batches/s, GPU_mem=2.39G, dloss=82.4, gloss=0.00479]
# Epoch 153/300: 100%|██████████| 2/2 [00:01<00:00,  1.75batches/s, GPU_mem=2.39G, dloss=83.4, gloss=0.00462]
# Epoch 154/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=83.2, gloss=0.00481]
# Epoch 155/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=84.5, gloss=0.00473]
# Epoch 156/300: 100%|██████████| 2/2 [00:01<00:00,  1.94batches/s, GPU_mem=2.39G, dloss=84.7, gloss=0.00488]
# Epoch 157/300: 100%|██████████| 2/2 [00:01<00:00,  1.84batches/s, GPU_mem=2.39G, dloss=83.7, gloss=0.00465]
# Epoch 158/300: 100%|██████████| 2/2 [00:01<00:00,  1.86batches/s, GPU_mem=2.39G, dloss=83.9, gloss=0.00553]
# Epoch 159/300: 100%|██████████| 2/2 [00:01<00:00,  1.83batches/s, GPU_mem=2.39G, dloss=84.2, gloss=0.00477]
# Epoch 160/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=81.8, gloss=0.00492]
# Epoch 161/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=83.4, gloss=0.0048]
# Epoch 162/300: 100%|██████████| 2/2 [00:01<00:00,  1.76batches/s, GPU_mem=2.39G, dloss=85.1, gloss=0.00474]
# Epoch 163/300: 100%|██████████| 2/2 [00:01<00:00,  1.84batches/s, GPU_mem=2.39G, dloss=84.1, gloss=0.00492]
# Epoch 164/300: 100%|██████████| 2/2 [00:00<00:00,  2.01batches/s, GPU_mem=2.39G, dloss=81.9, gloss=0.00486]
# Epoch 165/300: 100%|██████████| 2/2 [00:01<00:00,  1.73batches/s, GPU_mem=2.39G, dloss=83.9, gloss=0.00471]
# Epoch 166/300: 100%|██████████| 2/2 [00:01<00:00,  1.71batches/s, GPU_mem=2.39G, dloss=84.9, gloss=0.00466]
# Epoch 167/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=81.8, gloss=0.0052]
# Epoch 168/300: 100%|██████████| 2/2 [00:01<00:00,  1.67batches/s, GPU_mem=2.39G, dloss=84.5, gloss=0.00476]
# Epoch 169/300: 100%|██████████| 2/2 [00:01<00:00,  1.57batches/s, GPU_mem=2.39G, dloss=84.3, gloss=0.00461]
# Epoch 170/300: 100%|██████████| 2/2 [00:01<00:00,  1.58batches/s, GPU_mem=2.39G, dloss=84.4, gloss=0.00472]
# Epoch 171/300: 100%|██████████| 2/2 [00:01<00:00,  1.72batches/s, GPU_mem=2.39G, dloss=84.6, gloss=0.00457]
# Epoch 172/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=83.9, gloss=0.00475]
# Epoch 173/300: 100%|██████████| 2/2 [00:01<00:00,  1.76batches/s, GPU_mem=2.39G, dloss=81.9, gloss=0.00467]
# Epoch 174/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=82.1, gloss=0.00472]
# Epoch 175/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=82.8, gloss=0.0047]
# Epoch 176/300: 100%|██████████| 2/2 [00:01<00:00,  1.92batches/s, GPU_mem=2.39G, dloss=84.7, gloss=0.00581]
# Epoch 177/300: 100%|██████████| 2/2 [00:01<00:00,  1.73batches/s, GPU_mem=2.39G, dloss=85.4, gloss=0.00484]
# Epoch 178/300: 100%|██████████| 2/2 [00:01<00:00,  1.74batches/s, GPU_mem=2.39G, dloss=83.1, gloss=0.00475]
# Epoch 179/300: 100%|██████████| 2/2 [00:01<00:00,  1.75batches/s, GPU_mem=2.39G, dloss=84.9, gloss=0.00497]
# Epoch 180/300: 100%|██████████| 2/2 [00:01<00:00,  1.76batches/s, GPU_mem=2.39G, dloss=84.9, gloss=0.00532]
# Epoch 181/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=83.3, gloss=0.00476]
# Epoch 182/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=84, gloss=0.00455]
# Epoch 183/300: 100%|██████████| 2/2 [00:01<00:00,  1.86batches/s, GPU_mem=2.39G, dloss=84.6, gloss=0.00449]
# Epoch 184/300: 100%|██████████| 2/2 [00:01<00:00,  1.93batches/s, GPU_mem=2.39G, dloss=82.9, gloss=0.00434]
# Epoch 185/300: 100%|██████████| 2/2 [00:01<00:00,  1.83batches/s, GPU_mem=2.39G, dloss=85.7, gloss=0.00442]
# Epoch 186/300: 100%|██████████| 2/2 [00:01<00:00,  1.71batches/s, GPU_mem=2.39G, dloss=83.7, gloss=0.00554]
# Epoch 187/300: 100%|██████████| 2/2 [00:01<00:00,  1.83batches/s, GPU_mem=2.39G, dloss=81.9, gloss=0.00488]
# Epoch 188/300: 100%|██████████| 2/2 [00:01<00:00,  1.71batches/s, GPU_mem=2.39G, dloss=84.5, gloss=0.00459]
# Epoch 189/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=84.5, gloss=0.00447]
# Epoch 190/300: 100%|██████████| 2/2 [00:01<00:00,  1.76batches/s, GPU_mem=2.39G, dloss=85.7, gloss=0.00476]
# Epoch 191/300: 100%|██████████| 2/2 [00:01<00:00,  1.78batches/s, GPU_mem=2.39G, dloss=82.6, gloss=0.00445]
# Epoch 192/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=85.3, gloss=0.00454]
# Epoch 193/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=86, gloss=0.00427]
# Epoch 194/300: 100%|██████████| 2/2 [00:01<00:00,  1.86batches/s, GPU_mem=2.39G, dloss=83.9, gloss=0.00438]
# Epoch 195/300: 100%|██████████| 2/2 [00:01<00:00,  1.73batches/s, GPU_mem=2.39G, dloss=84.7, gloss=0.00444]
# Epoch 196/300: 100%|██████████| 2/2 [00:01<00:00,  1.73batches/s, GPU_mem=2.39G, dloss=85.7, gloss=0.0043]
# Epoch 197/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=84.3, gloss=0.00418]
# Epoch 198/300: 100%|██████████| 2/2 [00:01<00:00,  1.88batches/s, GPU_mem=2.39G, dloss=84.1, gloss=0.0045]
# Epoch 199/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=86.4, gloss=0.00432]
# Epoch 200/300: 100%|██████████| 2/2 [00:00<00:00,  2.30batches/s, GPU_mem=2.39G, dloss=84, gloss=0.00462]
# Epoch 201/300: 100%|██████████| 2/2 [00:00<00:00,  2.39batches/s, GPU_mem=2.39G, dloss=84, gloss=0.00432]
# Epoch 202/300: 100%|██████████| 2/2 [00:00<00:00,  2.42batches/s, GPU_mem=2.39G, dloss=83.3, gloss=0.00476]
# Epoch 203/300: 100%|██████████| 2/2 [00:00<00:00,  2.13batches/s, GPU_mem=2.39G, dloss=84.6, gloss=0.00433]
# Epoch 204/300: 100%|██████████| 2/2 [00:00<00:00,  2.33batches/s, GPU_mem=2.39G, dloss=84.4, gloss=0.00469]
# Epoch 205/300: 100%|██████████| 2/2 [00:00<00:00,  2.25batches/s, GPU_mem=2.39G, dloss=84.2, gloss=0.00434]
# Epoch 206/300: 100%|██████████| 2/2 [00:00<00:00,  2.38batches/s, GPU_mem=2.39G, dloss=84.9, gloss=0.0042]
# Epoch 207/300: 100%|██████████| 2/2 [00:00<00:00,  2.39batches/s, GPU_mem=2.39G, dloss=85.8, gloss=0.00428]
# Epoch 208/300: 100%|██████████| 2/2 [00:01<00:00,  1.90batches/s, GPU_mem=2.39G, dloss=84.7, gloss=0.00466]
# Epoch 209/300: 100%|██████████| 2/2 [00:01<00:00,  1.87batches/s, GPU_mem=2.39G, dloss=87.4, gloss=0.00434]
# Epoch 210/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=84.2, gloss=0.00418]
# Epoch 211/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=85, gloss=0.00416]
# Epoch 212/300: 100%|██████████| 2/2 [00:01<00:00,  1.75batches/s, GPU_mem=2.39G, dloss=84, gloss=0.00509]
# Epoch 213/300: 100%|██████████| 2/2 [00:01<00:00,  1.70batches/s, GPU_mem=2.39G, dloss=84.1, gloss=0.00393]
# Epoch 214/300: 100%|██████████| 2/2 [00:01<00:00,  1.66batches/s, GPU_mem=2.39G, dloss=84, gloss=0.00406]
# Epoch 215/300: 100%|██████████| 2/2 [00:01<00:00,  1.70batches/s, GPU_mem=2.39G, dloss=84.7, gloss=0.00469]
# Epoch 216/300: 100%|██████████| 2/2 [00:01<00:00,  1.90batches/s, GPU_mem=2.39G, dloss=84.6, gloss=0.0044]
# Epoch 217/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=85.8, gloss=0.00432]
# Epoch 218/300: 100%|██████████| 2/2 [00:01<00:00,  1.83batches/s, GPU_mem=2.39G, dloss=85.4, gloss=0.00462]
# Epoch 219/300: 100%|██████████| 2/2 [00:01<00:00,  1.56batches/s, GPU_mem=2.39G, dloss=86.4, gloss=0.00392]
# Epoch 220/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=86, gloss=0.00428]
# Epoch 221/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=82.7, gloss=0.00414]
# Epoch 222/300: 100%|██████████| 2/2 [00:01<00:00,  1.75batches/s, GPU_mem=2.39G, dloss=84.8, gloss=0.00504]
# Epoch 223/300: 100%|██████████| 2/2 [00:01<00:00,  1.65batches/s, GPU_mem=2.39G, dloss=88.9, gloss=0.00427]
# Epoch 224/300: 100%|██████████| 2/2 [00:01<00:00,  1.58batches/s, GPU_mem=2.39G, dloss=85, gloss=0.00432]
# Epoch 225/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=84.8, gloss=0.00427]
# Epoch 226/300: 100%|██████████| 2/2 [00:01<00:00,  1.78batches/s, GPU_mem=2.39G, dloss=85.7, gloss=0.00404]
# Epoch 227/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=88.1, gloss=0.00427]
# Epoch 228/300: 100%|██████████| 2/2 [00:01<00:00,  1.71batches/s, GPU_mem=2.39G, dloss=88.4, gloss=0.0042]
# Epoch 229/300: 100%|██████████| 2/2 [00:01<00:00,  1.78batches/s, GPU_mem=2.39G, dloss=86.4, gloss=0.00406]
# Epoch 230/300: 100%|██████████| 2/2 [00:01<00:00,  1.78batches/s, GPU_mem=2.39G, dloss=85.4, gloss=0.004]
# Epoch 231/300: 100%|██████████| 2/2 [00:01<00:00,  1.83batches/s, GPU_mem=2.39G, dloss=85, gloss=0.00446]
# Epoch 232/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=85.6, gloss=0.00412]
# Epoch 233/300: 100%|██████████| 2/2 [00:01<00:00,  1.86batches/s, GPU_mem=2.39G, dloss=86, gloss=0.00403]
# Epoch 234/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=84.2, gloss=0.004]
# Epoch 235/300: 100%|██████████| 2/2 [00:01<00:00,  1.84batches/s, GPU_mem=2.39G, dloss=85.8, gloss=0.00404]
# Epoch 236/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=85.8, gloss=0.00406]
# Epoch 237/300: 100%|██████████| 2/2 [00:01<00:00,  1.72batches/s, GPU_mem=2.39G, dloss=86.4, gloss=0.00398]
# Epoch 238/300: 100%|██████████| 2/2 [00:01<00:00,  1.83batches/s, GPU_mem=2.39G, dloss=88, gloss=0.00433]
# Epoch 239/300: 100%|██████████| 2/2 [00:01<00:00,  1.54batches/s, GPU_mem=2.39G, dloss=86.5, gloss=0.00437]
# Epoch 240/300: 100%|██████████| 2/2 [00:01<00:00,  1.78batches/s, GPU_mem=2.39G, dloss=84.6, gloss=0.00406]
# Epoch 241/300: 100%|██████████| 2/2 [00:01<00:00,  1.74batches/s, GPU_mem=2.39G, dloss=87.6, gloss=0.00395]
# Epoch 242/300: 100%|██████████| 2/2 [00:01<00:00,  1.75batches/s, GPU_mem=2.39G, dloss=86.1, gloss=0.00406]
# Epoch 243/300: 100%|██████████| 2/2 [00:01<00:00,  1.69batches/s, GPU_mem=2.39G, dloss=86, gloss=0.00431]
# Epoch 244/300: 100%|██████████| 2/2 [00:01<00:00,  1.52batches/s, GPU_mem=2.39G, dloss=85.5, gloss=0.00381]
# Epoch 245/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=84.7, gloss=0.00395]
# Epoch 246/300: 100%|██████████| 2/2 [00:01<00:00,  1.86batches/s, GPU_mem=2.39G, dloss=88.1, gloss=0.00408]
# Epoch 247/300: 100%|██████████| 2/2 [00:01<00:00,  1.84batches/s, GPU_mem=2.39G, dloss=86, gloss=0.00401]
# Epoch 248/300: 100%|██████████| 2/2 [00:01<00:00,  1.83batches/s, GPU_mem=2.39G, dloss=85.2, gloss=0.00426]
# Epoch 249/300: 100%|██████████| 2/2 [00:01<00:00,  1.75batches/s, GPU_mem=2.39G, dloss=85.9, gloss=0.00377]
# Epoch 250/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=85.6, gloss=0.00399]
# Epoch 251/300: 100%|██████████| 2/2 [00:01<00:00,  1.86batches/s, GPU_mem=2.39G, dloss=86.4, gloss=0.00448]
# Epoch 252/300: 100%|██████████| 2/2 [00:01<00:00,  1.86batches/s, GPU_mem=2.39G, dloss=87.6, gloss=0.00407]
# Epoch 253/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=86.5, gloss=0.00379]
# Epoch 254/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=89.6, gloss=0.00395]
# Epoch 255/300: 100%|██████████| 2/2 [00:01<00:00,  1.84batches/s, GPU_mem=2.39G, dloss=88.4, gloss=0.00392]
# Epoch 256/300: 100%|██████████| 2/2 [00:01<00:00,  1.85batches/s, GPU_mem=2.39G, dloss=86.9, gloss=0.00382]
# Epoch 257/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=87.2, gloss=0.00389]
# Epoch 258/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=88, gloss=0.00374]
# Epoch 259/300: 100%|██████████| 2/2 [00:01<00:00,  1.78batches/s, GPU_mem=2.39G, dloss=87.5, gloss=0.00385]
# Epoch 260/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=85.5, gloss=0.00416]
# Epoch 261/300: 100%|██████████| 2/2 [00:01<00:00,  1.70batches/s, GPU_mem=2.39G, dloss=87.7, gloss=0.00378]
# Epoch 262/300: 100%|██████████| 2/2 [00:01<00:00,  1.72batches/s, GPU_mem=2.39G, dloss=86.4, gloss=0.00385]
# Epoch 263/300: 100%|██████████| 2/2 [00:01<00:00,  1.81batches/s, GPU_mem=2.39G, dloss=84.5, gloss=0.00393]
# Epoch 264/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=86.3, gloss=0.00398]
# Epoch 265/300: 100%|██████████| 2/2 [00:01<00:00,  1.72batches/s, GPU_mem=2.39G, dloss=87.8, gloss=0.00397]
# Epoch 266/300: 100%|██████████| 2/2 [00:01<00:00,  1.66batches/s, GPU_mem=2.39G, dloss=84.8, gloss=0.00391]
# Epoch 267/300: 100%|██████████| 2/2 [00:01<00:00,  1.65batches/s, GPU_mem=2.39G, dloss=85.2, gloss=0.00393]
# Epoch 268/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=86.1, gloss=0.00401]
# Epoch 269/300: 100%|██████████| 2/2 [00:01<00:00,  1.70batches/s, GPU_mem=2.39G, dloss=86.9, gloss=0.00373]
# Epoch 270/300: 100%|██████████| 2/2 [00:01<00:00,  1.71batches/s, GPU_mem=2.39G, dloss=86.9, gloss=0.00386]
# Epoch 271/300: 100%|██████████| 2/2 [00:01<00:00,  1.76batches/s, GPU_mem=2.39G, dloss=86.9, gloss=0.00364]
# Epoch 272/300: 100%|██████████| 2/2 [00:01<00:00,  1.74batches/s, GPU_mem=2.39G, dloss=83.9, gloss=0.00373]
# Epoch 273/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=86.3, gloss=0.00362]
# Epoch 274/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=87.8, gloss=0.00369]
# Epoch 275/300: 100%|██████████| 2/2 [00:01<00:00,  1.70batches/s, GPU_mem=2.39G, dloss=87.8, gloss=0.0036]
# Epoch 276/300: 100%|██████████| 2/2 [00:01<00:00,  1.77batches/s, GPU_mem=2.39G, dloss=87.4, gloss=0.00389]
# Epoch 277/300: 100%|██████████| 2/2 [00:01<00:00,  1.76batches/s, GPU_mem=2.39G, dloss=87.2, gloss=0.0039]
# Epoch 278/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=86.6, gloss=0.00476]
# Epoch 279/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=86.9, gloss=0.00387]
# Epoch 280/300: 100%|██████████| 2/2 [00:01<00:00,  1.75batches/s, GPU_mem=2.39G, dloss=86.1, gloss=0.004]
# Epoch 281/300: 100%|██████████| 2/2 [00:01<00:00,  1.86batches/s, GPU_mem=2.39G, dloss=88.3, gloss=0.00391]
# Epoch 282/300: 100%|██████████| 2/2 [00:01<00:00,  1.84batches/s, GPU_mem=2.39G, dloss=89.1, gloss=0.00361]
# Epoch 283/300: 100%|██████████| 2/2 [00:01<00:00,  1.80batches/s, GPU_mem=2.39G, dloss=88.1, gloss=0.00379]
# Epoch 284/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=87.7, gloss=0.00378]
# Epoch 285/300: 100%|██████████| 2/2 [00:01<00:00,  1.75batches/s, GPU_mem=2.39G, dloss=86.3, gloss=0.0037]
# Epoch 286/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=86.4, gloss=0.00438]
# Epoch 287/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=89.5, gloss=0.00381]
# Epoch 288/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=88.3, gloss=0.00465]
# Epoch 289/300: 100%|██████████| 2/2 [00:01<00:00,  1.73batches/s, GPU_mem=2.39G, dloss=85.6, gloss=0.00382]
# Epoch 290/300: 100%|██████████| 2/2 [00:01<00:00,  1.57batches/s, GPU_mem=2.39G, dloss=87.2, gloss=0.00383]
# Epoch 291/300: 100%|██████████| 2/2 [00:01<00:00,  1.82batches/s, GPU_mem=2.39G, dloss=86.4, gloss=0.00394]
# Epoch 292/300: 100%|██████████| 2/2 [00:01<00:00,  1.86batches/s, GPU_mem=2.39G, dloss=89, gloss=0.0037]
# Epoch 293/300: 100%|██████████| 2/2 [00:01<00:00,  1.84batches/s, GPU_mem=2.39G, dloss=87.2, gloss=0.00377]
# Epoch 294/300: 100%|██████████| 2/2 [00:01<00:00,  1.76batches/s, GPU_mem=2.39G, dloss=87.8, gloss=0.0039]
# Epoch 295/300: 100%|██████████| 2/2 [00:01<00:00,  1.79batches/s, GPU_mem=2.39G, dloss=86.7, gloss=0.00389]
# Epoch 296/300: 100%|██████████| 2/2 [00:01<00:00,  1.66batches/s, GPU_mem=2.39G, dloss=86.4, gloss=0.004]
# Epoch 297/300: 100%|██████████| 2/2 [00:01<00:00,  1.67batches/s, GPU_mem=2.39G, dloss=86.7, gloss=0.00366]
# Epoch 298/300: 100%|██████████| 2/2 [00:01<00:00,  1.70batches/s, GPU_mem=2.39G, dloss=86.8, gloss=0.00375]
# Epoch 299/300: 100%|██████████| 2/2 [00:01<00:00,  1.72batches/s, GPU_mem=2.39G, dloss=89.3, gloss=0.00378]

# %% [markdown]
# # Test

# %%
ckpt = torch.load('srgan.pt')
test_generator = ckpt['generator'].to(device).float()
test_generator.eval()
test_loader = LoadImages('data/test')  # test dataset: Set5

# %%
with torch.no_grad():
    for image, image_name in test_loader:
        image = image.to(device)
        pred = test_generator(image).cpu()
        pred_img = transforms.ToPILImage()(pred.squeeze(0))

        pred_img.save(f'output/srgan/srgan_{image_name}')
